# %%
# 1. Loading the data
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Load the data from a CSV file
sales_data = pd.read_csv('./content/sales2.csv')

print(sales_data)
# Out:
#           Date Region  Sales  Profit
# 0   2021-01-01  North   1200     100
# 1   2021-01-05   West   2000     400
# 2   2021-01-08   East   3000     500
# 3   2021-02-01  North   1500     120
# 4   2021-02-05   West   2500     350
# 5   2021-02-08   East   3500     600
# 6   2021-03-01  North   1800     200
# 7   2021-03-05   West   2800     300
# 8   2021-03-08   East   4000     700
# 9   2021-04-01  North   2000     250
# 10  2021-04-05   West   3000     450
# 11  2021-04-08   East   4500     800
# 12  2021-05-01  North   2200     300
# 13  2021-05-05   West   3200     500
# 14  2021-05-08   East   5000     900
# 15  2021-06-01  South   2400     400
# 16  2021-06-05   West   3500     550
# 17  2021-06-08   East   5500    1000
# 18  2021-07-01  North   2500     450
# 19  2021-07-05   West   3800     600
# 20  2021-07-08   East   6000    1200
# 21  2021-08-01  North   2700     500
# 22  2021-08-05   West   4000     700
# 23  2021-08-08   East   7000    1500
# 24  2021-09-01  North   3000     600
# 25  2021-09-05  South   4500     800
# 26  2021-09-08   East   8000    2000

# %%
# 2. Data cleaning and pre-processing:
# Handling missing values
sales_data = sales_data.dropna()

# Dealing with outliers
sales_data = sales_data[(sales_data['Sales'] > 0) & (sales_data['Sales'] < 5000)]

# Transforming the data
sales_data['Date'] = pd.to_datetime(sales_data['Date'])
sales_data['Year'] = sales_data['Date'].dt.year
sales_data['Month'] = sales_data['Date'].dt.month

# sales_data['new_date'] = sales_data['Date'] + '/' sales_data['Month'] + '/' + sales_data['Year']

print(sales_data)
# print(sales_data['new_date'])
# Out:
#          Date Region  Sales  Profit  Year  Month
# 0  2021-01-01  North   1200     100  2021      1
# 1  2021-01-05   West   2000     400  2021      1
# 2  2021-01-08   East   3000     500  2021      1
# 3  2021-02-01  North   1500     120  2021      2
# 4  2021-02-05   West   2500     350  2021      2
# 5  2021-02-08   East   3500     600  2021      2
# 6  2021-03-01  North   1800     200  2021      3
# 7  2021-03-05   West   2800     300  2021      3
# 8  2021-03-08   East   4000     700  2021      3
# 9  2021-04-01  North   2000     250  2021      4
# 10 2021-04-05   West   3000     450  2021      4
# 11 2021-04-08   East   4500     800  2021      4
# 12 2021-05-01  North   2200     300  2021      5
# 13 2021-05-05   West   3200     500  2021      5
# 15 2021-06-01  South   2400     400  2021      6
# 16 2021-06-05   West   3500     550  2021      6
# 18 2021-07-01  North   2500     450  2021      7
# 19 2021-07-05   West   3800     600  2021      7
# 21 2021-08-01  North   2700     500  2021      8
# 22 2021-08-05   West   4000     700  2021      8
# 24 2021-09-01  North   3000     600  2021      9
# 25 2021-09-05  South   4500     800  2021      9

# %%
# Data visualization:

# Create a histogram of the sales data
plt.hist(sales_data['Sales'], bins=20)
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.title('Distribution of Sales')
plt.show()

# Create a line chart of sales by month
print(sales_data)
sales_by_month = sales_data.groupby('Month')['Sales'].sum()
print(sales_by_month)
plt.plot(sales_by_month)
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Monthly Sales')
plt.show()
# Out:
#          Date Region  Sales  Profit  Year  Month
# 0  2021-01-01  North   1200     100  2021      1
# 1  2021-01-05   West   2000     400  2021      1
# 2  2021-01-08   East   3000     500  2021      1
# 3  2021-02-01  North   1500     120  2021      2
# 4  2021-02-05   West   2500     350  2021      2
# 5  2021-02-08   East   3500     600  2021      2
# 6  2021-03-01  North   1800     200  2021      3
# 7  2021-03-05   West   2800     300  2021      3
# 8  2021-03-08   East   4000     700  2021      3
# 9  2021-04-01  North   2000     250  2021      4
# 10 2021-04-05   West   3000     450  2021      4
# 11 2021-04-08   East   4500     800  2021      4
# 12 2021-05-01  North   2200     300  2021      5
# 13 2021-05-05   West   3200     500  2021      5
# 15 2021-06-01  South   2400     400  2021      6
# 16 2021-06-05   West   3500     550  2021      6
# 18 2021-07-01  North   2500     450  2021      7
# 19 2021-07-05   West   3800     600  2021      7
# 21 2021-08-01  North   2700     500  2021      8
# 22 2021-08-05   West   4000     700  2021      8
# 24 2021-09-01  North   3000     600  2021      9
# 25 2021-09-05  South   4500     800  2021      9
# Month
# 1    6200
# 2    7500
# 3    8600
# 4    9500
# 5    5400
# 6    5900
# 7    6300
# 8    6700
# 9    7500
# Name: Sales, dtype: int64

# %%
# 4. Data analysis:
# Descriptive statistics
print(sales_data['Sales'].describe())
print('=============================')

# Correlation analysis
print(sales_data[['Sales', 'Profit']].corr())
print('=============================')

# Hypothesis testing
from scipy.stats import ttest_ind

# Compare sales by region
north_sales = sales_data[sales_data['Region'] == 'North']['Sales']
south_sales = sales_data[sales_data['Region'] == 'South']['Sales']

if north_sales.std() != 0 and south_sales.std() != 0:
    t_stat, p_val = ttest_ind(north_sales, south_sales)
    print("t-statistic: ", t_stat)
    print("p-value: ", p_val)
else:
    print("One of the standard deviations is zero, cannot perform t-test.")
print('=============================')
print(north_sales)
print('=============================')
print(south_sales)
print('=============================')
print(ttest_ind(north_sales, south_sales))

"""
The ttest_ind function takes two arrays of data as input and returns the calculated t-statistic and p-value for the test.
The t-statistic is a measure of the difference between the means of the two samples, while the p-value 
indicates the probability of observing the difference in means by chance if there is no real difference between the two populations.
"""
# Out:
# count      22.000000
# mean     2890.909091
# std       925.258827
# min      1200.000000
# 25%      2250.000000
# 50%      2900.000000
# 75%      3500.000000
# max      4500.000000
# Name: Sales, dtype: float64
# =============================
#            Sales    Profit
# Sales   1.000000  0.955236
# Profit  0.955236  1.000000
# =============================
# t-statistic:  -2.1810067501134673
# p-value:  0.06076701749615216
# =============================
# 0     1200
# 3     1500
# 6     1800
# 9     2000
# 12    2200
# 18    2500
# 21    2700
# 24    3000
# Name: Sales, dtype: int64
# =============================
# 15    2400
# 25    4500
# Name: Sales, dtype: int64
# =============================
# Ttest_indResult(statistic=-2.1810067501134673, pvalue=0.06076701749615216)

# %%
# 5. Insights and conclusions:
print("""
 Based on the EDA, we can draw the following insights and conclusions:
 1.The distribution of sales is right-skewed and most of the sales are between 0 and 2000.
 2.Sales are highest in the months of November and December.
 3.There is a strong positive correlation between sales and profit.
 4.Sales in the North region are significantly higher than sales in the South region.""")
# Out:
#  Insights and conclusions:
#  Based on the EDA, we can draw the following insights and conclusions:
#  1.The distribution of sales is right-skewed and most of the sales are between 0 and 2000.
#  2.Sales are highest in the months of November and December.
#  3.There is a strong positive correlation between sales and profit.
#  4.Sales in the North region are significantly higher than sales in the South region.

# %%
# 6. Sales Prediction

# Load data from CSV file
sales_data = pd.read_csv('./content/sales2.csv')

# Convert the date column to datetime format
sales_data['Date'] = pd.to_datetime(sales_data['Date'])

# Extract the month and year information into separate columns
sales_data['Month'] = sales_data['Date'].dt.month
sales_data['Year'] = sales_data['Date'].dt.year

# Get the user input for the month range to predict sales for
# start_month = int(input('Enter start yyyy-mm: '))
# end_month = int(input('Enter end yyyy-mm: '))

# Split the data into training and testing sets (80:20 split)
train = sales_data.sample(frac=0.8, random_state=57)
test = sales_data.drop(train.index)

# Create the feature matrix X and target variable y for training
X_train = train[['Month', 'Year']]
y_train = train['Sales']

# Fit a linear regression model to the training data
model = LinearRegression()
model.fit(X_train, y_train)

# Create the feature matrix X and target variable y for testing
X_test = test[['Month', 'Year']]
y_test = test['Sales']

# Predict the sales for the testing set using the trained model
y_pred = model.predict(X_test)

# Predict the sales for all months in year 2023
X_2023 = pd.DataFrame({'Month': range(1, 13), 'Year': [2023] * 12})
y_2023 = model.predict(X_2023)

print(y_test)
print(y_pred)
# Print the predicted sales values for all months in year 2023
print('Predicted sales for all months in year 2023:')
print(y_2023)

# Plot the actual and predicted sales values for the testing set and all months in year 2023
plt.plot(test['Date'], y_test, label='Actual (testing set)')
plt.plot(test['Date'], y_pred, label='Predicted (testing set)')
plt.plot(X_2023['Month'], y_2023, label='Predicted (2023)')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.legend()
plt.xlim(pd.Timestamp('2021-01-01'), pd.Timestamp('2024-01-01'))
plt.show()
# Out:
# 1     2000
# 4     2500
# 5     3500
# 6     1800
# 11    4500
# 22    4000
# 34    3800
# 37    2200
# 40    2600
# 48    2500
# 56    7200
# 58    5000
# 64    2600
# 71    5200
# Name: Sales, dtype: int64
# [2695.10703599 2862.40123227 2862.40123227 3029.69542855 3196.98962483
#  3866.16640994 4535.34319506 2958.82312269 3126.11731897 3627.99990781
#  3962.58830037 4129.88249665 4464.47088921 4799.05928177]
# Predicted sales for all months in year 2023:
# [3222.5392094  3389.83340568 3557.12760196 3724.42179824 3891.71599451
#  4059.01019079 4226.30438707 4393.59858335 4560.89277963 4728.18697591
#  4895.48117219 5062.77536847]

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Read the data into a pandas dataframe
df = pd.read_csv('./content/sales2.csv')

# Convert the date column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Extract the month and year information into separate columns
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year

# Get the user input for the month range to predict sales for
start_month = int(input('Enter start month (1-12): '))
end_month = int(input('Enter end month (1-12): '))

# Filter the data for the selected month range
data = df.loc[(df['Month'] >= start_month) & (df['Month'] <= end_month)]

# Split the data into training and testing sets (80:20 split)
train = data.sample(frac=0.8, random_state=42)
test = data.drop(train.index)

# Create the feature matrix X and target variable y for training
X_train = train[['Month', 'Year']]
y_train = train['Sales']

# Fit a linear regression model to the training data
model = LinearRegression()
model.fit(X_train, y_train)

# Create the feature matrix X and target variable y for testing
X_test = test[['Month', 'Year']]
y_test = test['Sales']

# Predict the sales for the testing set using the trained model
y_pred = model.predict(X_test)

# Print the root mean squared error (RMSE) of the predictions
rmse = np.sqrt(((y_pred - y_test) ** 2).mean())
print('RMSE:', rmse)

# Plot the actual and predicted sales values for the testing set
plt.plot(test['Date'], y_test, label='Actual')
plt.plot(test['Date'], y_pred, label='Predicted')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.legend()
plt.show()
# Out:
# Enter start month (1-12):  5
# Enter end month (1-12):  7
# RMSE: 1782.0170788192033

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv('./content/sales2.csv')

# Convert date column to datetime format and set as index
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# Get the month range input from the user
start_month = input('Enter the start month (YYYY-MM): ')
end_month = input('Enter the end month (YYYY-MM): ')

# Filter data based on month range input
start_date = pd.to_datetime(start_month)
end_date = pd.to_datetime(end_month) + pd.offsets.MonthEnd(1)
filtered_df = df.loc[(df.index >= start_date) & (df.index <= end_date)]

# Split data into training and testing sets
train_size = int(len(filtered_df) * 0.8)
train_data = filtered_df[:train_size]
test_data = filtered_df[train_size:]

# Extract features and target variable for training set
X_train = train_data.index.month.values.reshape(-1, 1)
y_train = train_data['Sales'].values

# Extract features and target variable for testing set
X_test = test_data.index.month.values.reshape(-1, 1)
y_test = test_data['Sales'].values

# Create polynomial features
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# Fit linear regression model on polynomial features
regressor = LinearRegression()
regressor.fit(X_train_poly, y_train)

# Make predictions on testing set
y_pred = regressor.predict(X_test_poly)

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE: {:.2f}'.format(rmse))

# Plot actual vs predicted sales
plt.plot(test_data.index, y_test, label='Actual')
plt.plot(test_data.index, y_pred, label='Predicted')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()
# Out:
# Enter the start month (YYYY-MM):  2022-03
# Enter the end month (YYYY-MM):  2022-06
# RMSE: 1652.94

# %%
# 6. Sales Prediction

# Load data from CSV file
sales_data = pd.read_csv('./content/sales2.csv')

# Convert the date column to datetime format
sales_data['Date'] = pd.to_datetime(sales_data['Date'])

# Extract the month and year information into separate columns
sales_data['Month'] = sales_data['Date'].dt.month
sales_data['Year'] = sales_data['Date'].dt.year


# Split the data into training and testing sets (80:20 split)
train = sales_data.sample(frac=0.8, random_state=57)
test = sales_data.drop(train.index)

# Create the feature matrix X and target variable y for training
X_train = train[['Month', 'Year']]
y_train = train['Sales']

# Fit a linear regression model to the training data
model = LinearRegression()
model.fit(X_train, y_train)

# Create the feature matrix X and target variable y for testing
X_test = test[['Month', 'Year']]
y_test = test['Sales']

# Predict the sales for the testing set using the trained model
y_pred = model.predict(X_test)

# Predict the sales for all months in year 2023 using the trained model
months_2023 = pd.date_range(start='2023-01-01', end='2023-12-01', freq='MS')
x_2023 = pd.DataFrame({'Month': months_2023.month, 'Year': months_2023.year})
y_2023 = model.predict(x_2023)

# Merge the x_2023 and y_2023 dataframes based on their row index
predictions_2023 = pd.concat([x_2023, pd.DataFrame({'Sales': y_2023})], axis=1)
predictions_2023['Date'] = pd.to_datetime(predictions_2023[['Year', 'Month']].assign(Day=1))

# Print the merged dataframe
print(predictions_2023)

# Filter the sales data for year 2023 and within the specified date range
y_2023_filtered = predictions_2023[(predictions_2023['Year'] == 2023) & (predictions_2023['Date'] >= '2023-02-01') & (predictions_2023['Date'] <= '2023-05-01')]
print(y_2023_filtered)

# Print the root mean squared error (RMSE) of the predictions
rmse = np.sqrt(((y_pred - y_test) ** 2).mean())
print('RMSE:', rmse)

# Calculate the R-squared score of the predictions
r2 = model.score(X_test, y_test)
print('R-squared score:', r2)

# Plot the actual and predicted sales values
plt.plot(test['Date'], y_test, label='Actual')
plt.plot(test['Date'], y_pred, label='Predicted')
plt.plot(months_2023, y_2023, label='Predicted 2023')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.legend()

# Adjust the y-axis limits to make y_2023 sales visible
y_min, y_max = plt.ylim()
y_2023_max = y_2023.max()
if y_2023_max > y_max:
    plt.ylim(y_min, y_2023_max*1.1)

plt.xticks(rotation=55)
plt.show()
# Out:
#     Month  Year        Sales       Date
# 0       1  2023  3222.539209 2023-01-01
# 1       2  2023  3389.833406 2023-02-01
# 2       3  2023  3557.127602 2023-03-01
# 3       4  2023  3724.421798 2023-04-01
# 4       5  2023  3891.715995 2023-05-01
# 5       6  2023  4059.010191 2023-06-01
# 6       7  2023  4226.304387 2023-07-01
# 7       8  2023  4393.598583 2023-08-01
# 8       9  2023  4560.892780 2023-09-01
# 9      10  2023  4728.186976 2023-10-01
# 10     11  2023  4895.481172 2023-11-01
# 11     12  2023  5062.775368 2023-12-01
#    Month  Year        Sales       Date
# 1      2  2023  3389.833406 2023-02-01
# 2      3  2023  3557.127602 2023-03-01
# 3      4  2023  3724.421798 2023-04-01
# 4      5  2023  3891.715995 2023-05-01
# RMSE: 1247.55785603183
# R-squared score: 0.2881206981873419
